# %%
import pandas as pd
import screed
import seaborn as sns
from matplotlib import rc_context
tall_size = (12,24)
norm_size = (18,12)
mpl_params = {'figure.autolayout': True,
               'axes.titlesize': 20,
               'axes.labelsize': 16,
               'ytick.labelsize': 14,
               'xtick.labelsize': 14
               }
sns.set(style="whitegrid", rc=mpl_params)
sns.set_palette("Paired", desat=.6)

# %%
lamp3 = [len(r.sequence) for r in screed.open('../../data/lamp3.fasta')]

# %%
lamp10 = [len(r.sequence) for r in screed.open('../../data/lamp10.fasta')]

# %%
lamp11 = [len(r.sequence) for r in screed.open('../../data/lamp11.fasta')]

# %%
lamp12 = [len(r.sequence) for r in screed.open('../../data/lamp12.fasta')]

# %%
lamp3 = pd.DataFrame(lamp3, columns=['length'])
lamp10 = pd.DataFrame(lamp10, columns=['length'])
lamp11 = pd.DataFrame(lamp11, columns=['length'])
lamp12 = pd.DataFrame(lamp12, columns=['length'])

# %%
lamp3.hist(bins=100)
lamp10.hist(bins=100)
lamp11.hist(bins=100)
lamp12.hist(bins=100)
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x20dcf150>]], dtype=object)

# %%
lamp3.sort(columns='length', ascending=False)[:1000].hist(bins=50)
lamp10.sort(columns='length', ascending=False)[:1000].hist(bins=50)
lamp11.sort(columns='length', ascending=False)[:1000].hist(bins=50)
lamp12.sort(columns='length', ascending=False)[:1000].hist(bins=50)
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x1df4ff50>]], dtype=object)

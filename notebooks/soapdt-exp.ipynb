# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dist = pd.read_csv('lamp6-soapdt-output.kmerFreq', header=None, names=['Frequency'])

# %%
plot(dist.Frequency[1:])
axis(xmin=0, xmax=50, ymin=0, ymax=5e7)
# Out:
# (0, 50, 0, 50000000.0)

# %%
covs = pd.read_csv('lamp6-soapdt-output.RPKM.Stat', delimiter='\t', skiprows=2)

# %%
covs[covs.RPKM > 1000].sort_index(by='RPKM')
# Out:
#         Transcript_ID  Length  Uniq_reads_num          RPKM
# 3699     scaffold3700     795           56156   1028.118657
# 225046       C2223107     105            8074   1119.215328
# 502985       C2778942     124            9860   1157.362571
# 452845       C2678667     120            9758   1183.569517
# 417218       C2607417     117            9620   1196.749938
# 834695       C3515305     174           15732   1315.978800
# 198570       C2170169     104            9682   1355.020740
# 216110       C2205235     105           11037   1529.945452
# 292454       C2357907     109           12193   1628.164493
# 588503       C2954195     133           14916   1632.356215
# 962002       C3817857     213           24572   1679.094375
# 16020   scaffold16021     331           38330   1685.485532
# 300728       C2374455     110           14067   1861.328408
# 254426       C2281858     107           16940   2304.325532
# 523009       C2818989     126           21876   2527.036839
# ...
